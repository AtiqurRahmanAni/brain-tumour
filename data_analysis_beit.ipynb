# %%
import glob
import numpy as np
import os
import torch
import torch.nn as nn
from PIL import Image
import cv2
import torch.nn.functional as F
from lime import lime_image
from skimage.segmentation import mark_boundaries
import torch_directml
import matplotlib.pyplot as plt
from transformers import BeitImageProcessor, BeitForImageClassification
import random

# %%
dml = torch_directml.device()

# %%
base_model = BeitForImageClassification.from_pretrained("microsoft/beit-base-patch16-224")
base_model.classifier = nn.Linear(in_features=768, out_features=2, bias=True)
base_model = base_model.to(dml)

# %%
model_path = "../trained-models/beit.pt"
base_model.load_state_dict(torch.load(model_path, map_location=torch.device('cpu')), strict=False)
# Out:
# _IncompatibleKeys(missing_keys=[], unexpected_keys=['beit.encoder.layer.0.attention.attention.relative_position_bias.relative_position_index', 'beit.encoder.layer.1.attention.attention.relative_position_bias.relative_position_index', 'beit.encoder.layer.2.attention.attention.relative_position_bias.relative_position_index', 'beit.encoder.layer.3.attention.attention.relative_position_bias.relative_position_index', 'beit.encoder.layer.4.attention.attention.relative_position_bias.relative_position_index', 'beit.encoder.layer.5.attention.attention.relative_position_bias.relative_position_index', 'beit.encoder.layer.6.attention.attention.relative_position_bias.relative_position_index', 'beit.encoder.layer.7.attention.attention.relative_position_bias.relative_position_index', 'beit.encoder.layer.8.attention.attention.relative_position_bias.relative_position_index', 'beit.encoder.layer.9.attention.attention.relative_position_bias.relative_position_index', 'beit.encoder.layer.10.attention.attention.relative_position_bias.relative_position_index', 'beit.encoder.layer.11.attention.attention.relative_position_bias.relative_position_index'])

# %%
image_processor = BeitImageProcessor.from_pretrained("microsoft/beit-base-patch16-224") 

def my_transform(image):
    pil_image = Image.fromarray(image)
    pixel_values = image_processor(pil_image, return_tensors="pt").pixel_values
    return pixel_values.squeeze()

# %%
def batch_predict(images):
    base_model.eval()
    batch = torch.stack(tuple(my_transform(i) for i in images), dim=0)
    batch = batch.to(dml)
    
    logits = base_model(batch).logits
    probs = F.softmax(logits, dim=1)
    return probs.detach().cpu().numpy()

# %%
def explain_image(image):
    explainer = lime_image.LimeImageExplainer()
    explanation = explainer.explain_instance(np.array(image), 
                                            batch_predict, # classification function
                                            hide_color=0, 
                                            batch_size=20,
                                            random_seed=240,
                                            num_samples=1000)
  
    temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=False, num_features=5, hide_rest=False)
    img_boundry2 = mark_boundaries(temp/255.0, mask)
  
    return img_boundry2

# %%
misclassified = [x.split("\\")[-1].split("_")[0] + '_' + x.split("\\")[-1].split("_")[1] for x in glob.glob("../images/lime/beit/*")]
# all_images = glob.glob("../splitted/test/0/*")
all_images = glob.glob("../splitted/test/1/*")

# %%
correctly_classified = []
for img_path in all_images:
    img_no = img_path.split("\\")[-1].split(".")[0]
    if img_no not in misclassified:
        correctly_classified.append(img_path)

sampled_images = random.sample(correctly_classified, 10)

# %%
images = []
for path in sampled_images:
    mask_no = path.split("\\")[-1].split("_")[0]
    folder_no = path.split("/")[-1].split("\\")[0]
    mask_path = f"../images/mask/{folder_no}/{mask_no}.png"

    img = cv2.imread(path)
    masked_image = explain_image(img)
    
    images.append((img, masked_image, cv2.imread(mask_path)))
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 8
#       5 mask_path = f"../images/mask/{folder_no}/{mask_no}.png"
#       7 img = cv2.imread(path)
# ----> 8 masked_image = explain_image(img)
#      10 images.append((img, masked_image, cv2.imread(mask_path)))
#
# Cell In[25], line 3, in explain_image(image)
#       1 def explain_image(image):
#       2     explainer = lime_image.LimeImageExplainer()
# ----> 3     explanation = explainer.explain_instance(np.array(image),
#       4                                             batch_predict, # classification function
#       5                                             hide_color=0,
#       6                                             batch_size=20,
#       7                                             random_seed=240,
#       8                                             num_samples=1000)
#      10     temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=False, num_features=5, hide_rest=False)
#      11     img_boundry2 = mark_boundaries(temp/255.0, mask)
#
# File e:\Study materials\Paper works\Brain tumour\brain-tumour\venv\lib\site-packages\lime\lime_image.py:198, in LimeImageExplainer.explain_instance(self, image, classifier_fn, labels, hide_color, top_labels, num_features, num_samples, batch_size, segmentation_fn, distance_metric, model_regressor, random_seed)
#     194     fudged_image[:] = hide_color
#     196 top = labels
# --> 198 data, labels = self.data_labels(image, fudged_image, segments,
#     199                                 classifier_fn, num_samples,
#     200                                 batch_size=batch_size)
#     202 distances = sklearn.metrics.pairwise_distances(
#     203     data,
#     204     data[0].reshape(1, -1),
#     205     metric=distance_metric
#     206 ).ravel()
#     208 ret_exp = ImageExplanation(image, segments)
#
# File e:\Study materials\Paper works\Brain tumour\brain-tumour\venv\lib\site-packages\lime\lime_image.py:261, in LimeImageExplainer.data_labels(self, image, fudged_image, segments, classifier_fn, num_samples, batch_size)
#     259 imgs.append(temp)
#     260 if len(imgs) == batch_size:
# --> 261     preds = classifier_fn(np.array(imgs))
#     262     labels.extend(preds)
#     263     imgs = []
#
# Cell In[24], line 3, in batch_predict(images)
#       1 def batch_predict(images):
#       2     base_model.eval()
# ----> 3     batch = torch.stack(tuple(my_transform(i) for i in images), dim=0)
#       4     batch = batch.to(dml)
#       6     logits = base_model(batch).logits
#
# Cell In[24], line 3, in <genexpr>(.0)
#       1 def batch_predict(images):
#       2     base_model.eval()
# ----> 3     batch = torch.stack(tuple(my_transform(i) for i in images), dim=0)
#       4     batch = batch.to(dml)
#       6     logits = base_model(batch).logits
#
# Cell In[23], line 5, in my_transform(image)
#       3 def my_transform(image):
#       4     pil_image = Image.fromarray(image)
# ----> 5     pixel_values = image_processor(pil_image, return_tensors="pt").pixel_values
#       6     return pixel_values.squeeze()
#
# File e:\Study materials\Paper works\Brain tumour\brain-tumour\venv\lib\site-packages\transformers\models\beit\image_processing_beit.py:350, in BeitImageProcessor.__call__(self, images, segmentation_maps, **kwargs)
#     347 def __call__(self, images, segmentation_maps=None, **kwargs):
#     348     # Overrides the `__call__` method of the `Preprocessor` class such that the images and segmentation maps can both
#     349     # be passed in as positional arguments.
# --> 350     return super().__call__(images, segmentation_maps=segmentation_maps, **kwargs)
#
# File e:\Study materials\Paper works\Brain tumour\brain-tumour\venv\lib\site-packages\transformers\image_processing_utils.py:494, in BaseImageProcessor.__call__(self, images, **kwargs)
#     492 def __call__(self, images, **kwargs) -> BatchFeature:
#     493     """Preprocess an image or a batch of images."""
# --> 494     return self.preprocess(images, **kwargs)
#
# File e:\Study materials\Paper works\Brain tumour\brain-tumour\venv\lib\site-packages\transformers\models\beit\image_processing_beit.py:457, in BeitImageProcessor.preprocess(self, images, segmentation_maps, do_resize, size, resample, do_center_crop, crop_size, do_rescale, rescale_factor, do_normalize, image_mean, image_std, do_reduce_labels, return_tensors, data_format, **kwargs)
#     454 if do_normalize and (image_mean is None or image_std is None):
#     455     raise ValueError("Image mean and std must be specified if do_normalize is True.")
# --> 457 images = [
#     458     self._preprocess_image(
#     459         image=img,
#     460         do_resize=do_resize,
#     461         do_center_crop=do_center_crop,
#     462         do_rescale=do_rescale,
#     463         do_normalize=do_normalize,
#     464         resample=resample,
#     465         size=size,
#     466         rescale_factor=rescale_factor,
#     467         crop_size=crop_size,
#     468         image_mean=image_mean,
#     469         image_std=image_std,
#     470         data_format=data_format,
#     471     )
#     472     for img in images
#     473 ]
#     475 data = {"pixel_values": images}
#     477 if segmentation_maps is not None:
#
# File e:\Study materials\Paper works\Brain tumour\brain-tumour\venv\lib\site-packages\transformers\models\beit\image_processing_beit.py:458, in <listcomp>(.0)
#     454 if do_normalize and (image_mean is None or image_std is None):
#     455     raise ValueError("Image mean and std must be specified if do_normalize is True.")
#     457 images = [
# --> 458     self._preprocess_image(
#     459         image=img,
#     460         do_resize=do_resize,
#     461         do_center_crop=do_center_crop,
#     462         do_rescale=do_rescale,
#     463         do_normalize=do_normalize,
#     464         resample=resample,
#     465         size=size,
#     466         rescale_factor=rescale_factor,
#     467         crop_size=crop_size,
#     468         image_mean=image_mean,
#     469         image_std=image_std,
#     470         data_format=data_format,
#     471     )
#     472     for img in images
#     473 ]
#     475 data = {"pixel_values": images}
#     477 if segmentation_maps is not None:
#
# File e:\Study materials\Paper works\Brain tumour\brain-tumour\venv\lib\site-packages\transformers\models\beit\image_processing_beit.py:293, in BeitImageProcessor._preprocess_image(self, image, do_resize, size, resample, do_center_crop, crop_size, do_rescale, rescale_factor, do_normalize, image_mean, image_std, data_format)
#     291 # All transformations expect numpy arrays.
#     292 image = to_numpy_array(image)
# --> 293 image = self._preprocess(
#     294     image,
#     295     do_reduce_labels=False,
#     296     do_resize=do_resize,
#     297     size=size,
#     298     resample=resample,
#     299     do_center_crop=do_center_crop,
#     300     crop_size=crop_size,
#     301     do_rescale=do_rescale,
#     302     rescale_factor=rescale_factor,
#     303     do_normalize=do_normalize,
#     304     image_mean=image_mean,
#     305     image_std=image_std,
#     306 )
#     307 if data_format is not None:
#     308     image = to_channel_dimension_format(image, data_format)
#
# File e:\Study materials\Paper works\Brain tumour\brain-tumour\venv\lib\site-packages\transformers\models\beit\image_processing_beit.py:262, in BeitImageProcessor._preprocess(self, image, do_reduce_labels, do_resize, size, resample, do_center_crop, crop_size, do_rescale, rescale_factor, do_normalize, image_mean, image_std)
#     259     image = self.reduce_label(image)
#     261 if do_resize:
# --> 262     image = self.resize(image=image, size=size, resample=resample)
#     264 if do_center_crop:
#     265     image = self.center_crop(image=image, size=crop_size)
#
# File e:\Study materials\Paper works\Brain tumour\brain-tumour\venv\lib\site-packages\transformers\models\beit\image_processing_beit.py:166, in BeitImageProcessor.resize(self, image, size, resample, data_format, **kwargs)
#     164 if "height" not in size or "width" not in size:
#     165     raise ValueError(f"The `size` argument must contain `height` and `width` keys. Got {size.keys()}")
# --> 166 return resize(
#     167     image, size=(size["height"], size["width"]), resample=resample, data_format=data_format, **kwargs
#     168 )
#
# File e:\Study materials\Paper works\Brain tumour\brain-tumour\venv\lib\site-packages\transformers\image_transforms.py:309, in resize(image, size, resample, reducing_gap, data_format, return_numpy)
#     307 height, width = size
#     308 # PIL images are in the format (width, height)
# --> 309 resized_image = image.resize((width, height), resample=resample, reducing_gap=reducing_gap)
#     311 if return_numpy:
#     312     resized_image = np.array(resized_image)
#
# File e:\Study materials\Paper works\Brain tumour\brain-tumour\venv\lib\site-packages\PIL\Image.py:2174, in Image.resize(self, size, resample, box, reducing_gap)
#    2166             self = Image.reduce(self, factor, box=reduce_box)
#    2167         box = (
#    2168             (box[0] - reduce_box[0]) / factor_x,
#    2169             (box[1] - reduce_box[1]) / factor_y,
#    2170             (box[2] - reduce_box[0]) / factor_x,
#    2171             (box[3] - reduce_box[1]) / factor_y,
#    2172         )
# -> 2174 return self._new(self.im.resize(size, resample, box))
#
# KeyboardInterrupt:

# %%
fig, axes = plt.subplots(3, 10, figsize=(20, 6))

for i in range(len(sampled_images)):
    axes[0, i].axis("off")
    axes[0, i].imshow(images[i][0])
    
    axes[1, i].axis("off")
    axes[1, i].imshow(images[i][1])
    
    axes[2, i].axis("off")
    axes[2, i].imshow(images[i][2])
    
plt.show()
